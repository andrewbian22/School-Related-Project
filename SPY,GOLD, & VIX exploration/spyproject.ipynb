# %%
import pandas as pd

# %%
spy = pd.read_csv('/content/drive/MyDrive/12th Grade/Machine Learning/SPY Prediction/SPY.csv')

# %%
au = pd.read_csv('/content/drive/MyDrive/12th Grade/Machine Learning/SPY Prediction/gold.csv')

# %%
vix = pd.read_csv('/content/drive/MyDrive/12th Grade/Machine Learning/SPY Prediction/vix-daily_csv.csv')

# %% [markdown]
# The goal is to understand the relationship (if any) between the price of the S&P500, gold, and the VIX (implied volatility).
#
# With this information try to predict the price of the SPY or at least the movement of the stock

# %%
spy
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2004-01-05  111.690002  112.519997  111.589996  112.440002   77.002022
# 1     2004-01-06  112.160004  112.730003  112.000000  112.550003   77.077339
# 2     2004-01-07  112.389999  113.059998  111.889999  112.930000   77.337578
# 3     2004-01-08  113.250000  113.410004  112.769997  113.379997   77.645744
# 4     2004-01-09  112.830002  113.500000  112.269997  112.389999   76.967751
# ...          ...         ...         ...         ...         ...         ...
# 4193  2020-08-31  350.350006  351.299988  349.059998  349.309998  332.732239
# 4194  2020-09-01  350.209991  352.709991  349.239990  352.600006  335.866150
# 4195  2020-09-02  354.670013  358.750000  353.429993  357.700012  340.724152
# 4196  2020-09-03  355.869995  356.380005  342.589996  345.390015  328.998291
# 4197  2020-09-04  346.130005  347.829987  334.869995  342.570007  326.312195
#
#          Volume
# 0      27959800
# ...

# %%
au
# Out:
#             Date    Open     High      Low   Close  Volume Currency
# 0     2000-01-04   289.5   289.50   280.00   283.7   21621      USD
# 1     2000-01-05   283.7   285.00   281.00   282.1   25448      USD
# 2     2000-01-06   281.6   282.80   280.20   282.4   19055      USD
# 3     2000-01-07   282.5   284.50   282.00   282.9   11266      USD
# 4     2000-01-10   282.4   283.90   281.80   282.7   30603      USD
# ...          ...     ...      ...      ...     ...     ...      ...
# 5698  2022-08-29  1748.4  1757.90  1731.40  1749.7  156220      USD
# 5699  2022-08-30  1749.8  1752.80  1732.90  1736.3  130664      USD
# 5700  2022-08-31  1735.5  1738.00  1720.60  1726.2  176731      USD
# 5701  2022-09-01  1723.0  1723.00  1699.10  1709.3  198618      USD
# 5702  2022-09-02  1707.9  1729.45  1707.05  1723.0       0      USD
#
# [5703 rows x 7 columns]

# %%
vix

# %%
spy.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Daily Percent Change'],
#       dtype='object')

# %%
au.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Currency',
#        'Daily Percent Change'],
#       dtype='object')

# %%
vix.columns
# Out:
# Index(['Date', 'VIX Open', 'VIX High', 'VIX Low', 'VIX Close'], dtype='object')

# %% [markdown]
# I need the column data to understand which feature columns I can compare to each other and may have a potential correleation

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Convert 'Date' column to datetime format
spy['Date'] = pd.to_datetime(spy['Date'])
vix['Date'] = pd.to_datetime(vix['Date'])

# Merge datasets on 'Date'
merged_data = pd.merge(spy, vix, on='Date', how='inner')

# Plotting

# Line plot of SPY Close prices
plt.figure(figsize=(12, 6))
plt.plot(merged_data['Date'], merged_data['Close'], label='SPY Close', color='blue')
plt.xlabel('Date')
plt.ylabel('SPY Close Price')
plt.title('SPY Close Price Over Time')
plt.legend()
plt.show()

# Line plot of VIX Close prices
plt.figure(figsize=(12, 6))
plt.plot(merged_data['Date'], merged_data['VIX Close'], label='VIX Close', color='red')
plt.xlabel('Date')
plt.ylabel('VIX Close Price')
plt.title('VIX Close Price Over Time')
plt.legend()
plt.show()

# Scatter plot of SPY Close prices against VIX Close prices
plt.figure(figsize=(12, 6))
plt.scatter(merged_data['Daily Percent Change'], merged_data['VIX Close'], color='green')
plt.xlabel('Daily Percent Change')
plt.ylabel('VIX Close Price')
plt.title('Scatter Plot of SPY Daily Percent Change vs VIX Close')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Daily Percent Change'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# Added daily precent change just to see correleations and make visualizations easier to read

# %%
spy['Date'] = pd.to_datetime(spy['Date'])

# Calculate daily percentage change from Open to Close
spy['Daily Percent Change'] = (spy['Close'] - spy['Open']) / spy['Open'] * 100

# %%
au['Date'] = pd.to_datetime(au['Date'])

# Calculate daily percentage change from Open to Close
au['Daily Percent Change'] = (au['Close'] - au['Open']) / au['Open'] * 100

# %%
vix['Date'] = pd.to_datetime(vix['Date'])

# Calculate daily percentage change from Open to Close
vix['Daily Percent Change'] = (vix['VIX Close'] - vix['VIX Open']) / vix['VIX Open'] * 100

# %%
# Convert 'Date' column to datetime format
spy['Date'] = pd.to_datetime(spy['Date'])
vix['Date'] = pd.to_datetime(vix['Date'])
au['Date'] = pd.to_datetime(au['Date'])

# Plotting

# Line plot of Daily Percent Change in SPY
plt.figure(figsize=(12, 6))
plt.plot(spy['Date'], spy['Daily Percent Change'], label='SPY', color='blue')
plt.xlabel('Date')
plt.ylabel('Daily Percent Change')
plt.title('SPY Daily Percent Change Over Time')
plt.legend()
plt.show()

# Line plot of Daily Percent Change in VIX
plt.figure(figsize=(12, 6))
plt.plot(vix['Date'], vix['Daily Percent Change'], label='VIX', color='red')
plt.xlabel('Date')
plt.ylabel('Daily Percent Change')
plt.title('VIX Daily Percent Change Over Time')
plt.legend()
plt.show()

# Line plot of Daily Percent Change in Gold
plt.figure(figsize=(12, 6))
plt.plot(au['Date'], au['Daily Percent Change'], label='Gold', color='green')
plt.xlabel('Date')
plt.ylabel('Daily Percent Change')
plt.title('Gold Daily Percent Change Over Time')
plt.legend()
plt.show()

# %%
# Convert 'Date' column to datetime format
spy['Date'] = pd.to_datetime(spy['Date'])
vix['Date'] = pd.to_datetime(vix['Date'])
au['Date'] = pd.to_datetime(au['Date'])

# Line plot of Daily Percent Change in SPY
plt.figure(figsize=(12, 6))
plt.plot(spy['Date'], spy['Daily Percent Change'], label='SPY', color='blue')
plt.plot(vix['Date'], vix['VIX Close'], label='VIX', color='red')
plt.plot(au['Date'], au['Daily Percent Change'], label='Gold', color='green')
plt.xlabel('Date')
plt.ylabel('Daily Percent Change')
plt.title('SPY Daily Percent Change Over Time')
plt.legend()
plt.show()

# %% [markdown]
# More visualizations for my own satisfaction and understanding

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have the three datasets loaded into DataFrames


# Convert 'Date' column to datetime format
spy['Date'] = pd.to_datetime(spy['Date'])
vix['Date'] = pd.to_datetime(vix['Date'])
au['Date'] = pd.to_datetime(au['Date'])

# Merge datasets on 'Date'
merged_data = pd.merge(spy, vix, on='Date', how='inner')
merged_data = pd.merge(merged_data, au, on='Date', how='inner')

# Pairplot to visualize relationships
sns.pairplot(merged_data[['Daily Percent Change_x', 'Daily Percent Change_y', 'Daily Percent Change']], kind='scatter')
plt.suptitle('Pairplot of Daily Percent Changes', y=1.02)
plt.show()

# Correlation matrix
correlation_matrix = merged_data[['Daily Percent Change_x', 'Daily Percent Change_y', 'Daily Percent Change']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Look at the relationship between Gold and the spy, are they inversely related use the vix as an extension of feature columns for the spy

# %% [markdown]
# Did a grid search and combined gold and spy datasets, also tested SVR and Linear Regression model to test which is better and find test correleation

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import numpy as np


# Merge datasets on 'Date' column
merged_data = pd.merge(spy, au, on='Date', suffixes=('_spy', '_gold'))

# Select relevant columns
X = merged_data[['Open_spy', 'High_spy', 'Low_spy', 'Open_gold', 'High_gold', 'Low_gold']]
y_spy = merged_data['Close_spy']
y_gold = merged_data['Close_gold']

# Train-test split
X_train, X_test, y_spy_train, y_spy_test, y_gold_train, y_gold_test = train_test_split(
    X, y_spy, y_gold, test_size=0.2, random_state=42
)

# RandomForestRegressor parameter grid
param_dist = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Randomized search for RandomForestRegressor
rf_model = RandomForestRegressor(random_state=42)
rf_random = RandomizedSearchCV(rf_model, param_distributions=param_dist, n_iter=10, cv=5, scoring='neg_mean_squared_error', random_state=42)
rf_random.fit(X_train, y_spy_train)

# Best parameters for RandomForestRegressor
best_rf_params = rf_random.best_params_

# Train RandomForestRegressor with best parameters
rf_best_model = RandomForestRegressor(**best_rf_params, random_state=42)
rf_best_model.fit(X_train, y_spy_train)

# Other models for comparison
models = {
    'Linear Regression': LinearRegression(),
    'SVR': SVR(),
    # Add more models if needed
}

# Train and evaluate other models
for name, model in models.items():
    pipeline = make_pipeline(StandardScaler(), model)
    pipeline.fit(X_train, y_spy_train)
    y_pred = pipeline.predict(X_test)
    mse = mean_squared_error(y_spy_test, y_pred)
    print(f'{name} MSE: {mse}')

# Find the strongest correlation
correlation_spy_gold = np.corrcoef(y_spy_test, y_gold_test)[0, 1]
print(f'Correlation between SPY and Gold: {correlation_spy_gold}')

# Additional analysis or plotting as needed
# Out:
# Linear Regression MSE: 0.7170500215538071
# SVR MSE: 55.22954551776978
# Correlation between SPY and Gold: 0.518361211413372
